# %%
import pandas as pd
import numpy as np

# %%
data = pd.DataFrame({"income":[25000,27000,29000,55000,58000,95000]})

# %%
print(data)
# Out:
#    income
# 0   25000
# 1   27000
# 2   29000
# 3   55000
# 4   58000
# 5   95000

# %%
data['income_bin']=pd.cut(data['income'],bins=3,labels=['low','mid','high'])

# %%
print(data)
# Out:
#    income income_bin
# 0   25000        low
# 1   27000        low
# 2   29000        low
# 3   55000        mid
# 4   58000        mid
# 5   95000       high
