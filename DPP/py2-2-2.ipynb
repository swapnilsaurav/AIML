# %%
import pandas as pd

# %%
data = pd.DataFrame({"bp":[120,130,118,145,160]})

# %%
print(data)
# Out:
#     bp
# 0  120
# 1  130
# 2  118
# 3  145
# 4  160

# %%
threshold = 140

# %%
data["bp_flag"] = (data["bp"] >= threshold).astype(int)

# %%
print(data)
# Out:
#     bp  bp_flag
# 0  120        0
# 1  130        0
# 2  118        0
# 3  145        1
# 4  160        1
